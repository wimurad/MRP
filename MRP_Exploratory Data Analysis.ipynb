# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame
from matplotlib.pyplot import pie
import matplotlib as mpl
import locale

NAICS_Wholesale_Data = pd.read_csv("E:\\RU Data Science\\Major Research Project\\Data Set\\20100003.csv"
                             , header = None, names = ['REF_DATE', 'GEO', 'DGUID', 'Sales, price and volume', 'North American Industry Classification System (NAICS)', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS', 'YEAR'])
#NAICS_Wholesale_Data.head()
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop(index = NAICS_Wholesale_Data.index[0])
NAICS_Wholesale_Data.shape
#NAICS_Wholesale_Data
# Out:
# (5100, 17)

# %%
df=pd.DataFrame(NAICS_Wholesale_Data)
NAICS_Wholesale_Data = df.fillna(0)
NAICS_Wholesale_Data['VALUE'] = NAICS_Wholesale_Data['VALUE'].astype(float)
df['VALUE'] = df['VALUE'].map('{:,.2f}'.format)
df
# Out:
#      REF_DATE     GEO           DGUID  \
# 1     2004-01  Canada  2016A000011124
# 2     2004-01  Canada  2016A000011124
# 3     2004-01  Canada  2016A000011124
# 4     2004-01  Canada  2016A000011124
# 5     2004-02  Canada  2016A000011124
# ...       ...     ...             ...
# 5096  2020-03  Canada  2016A000011124
# 5097  2020-03  Canada  2016A000011124
# 5098  2020-03  Canada  2016A000011124
# 5099  2020-03  Canada  2016A000011124
# 5100  2020-03  Canada  2016A000011124
#
#                                 Sales, price and volume  \
# 1                     Wholesale sales in current prices
# 2     Wholesale sales, chained Fisher price index (2...
# 3     Wholesale sales at 2012 prices (chained Fisher...
# 4               Wholesale sales at 2012 constant prices
# 5                     Wholesale sales in current prices
# ...                                                 ...
# 5096            Wholesale sales at 2012 constant prices
# ...

# %%
NAICS_Wholesale_Data = NAICS_Wholesale_Data.set_index("North American Industry Classification System (NAICS)")
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Wholesale trade [41]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Farm product merchant wholesalers [411]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Food, beverage and tobacco merchant wholesalers [413]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Personal and household goods merchant wholesalers [414]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Motor vehicle and motor vehicle parts and accessories merchant wholesalers  [415]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Building material and supplies merchant wholesalers [416]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Machinery, equipment and supplies merchant wholesalers [417]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Miscellaneous merchant wholesalers [418]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Pharmaceuticals and pharmacy supplies merchant wholesalers [41451]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.drop("Toiletries, cosmetics and sundries merchant wholesalers [41452]", axis=0)
NAICS_Wholesale_Data = NAICS_Wholesale_Data.reset_index()
NAICS_Wholesale_Data.shape
NAICS_Wholesale_Data
# Out:
#      North American Industry Classification System (NAICS) REF_DATE     GEO  \
# 0                      Food merchant wholesalers [4131]     2009-01  Canada
# 1                  Beverage merchant wholesalers [4132]     2009-01  Canada
# 2     Cigarette and tobacco product merchant wholesa...     2009-01  Canada
# 3     Textile, clothing and footwear merchant wholes...     2009-01  Canada
# 4     Home entertainment equipment and household app...     2009-01  Canada
# ...                                                 ...         ...     ...
# 3100    Recyclable material merchant wholesalers [4181]     2020-03  Canada
# 3101  Paper, paper product and disposable plastic pr...     2020-03  Canada
# 3102  Agricultural supplies merchant wholesalers [4183]     2020-03  Canada
# 3103  Chemical (except agricultural) and allied prod...     2020-03  Canada
# 3104    Other miscellaneous merchant wholesalers [4189]     2020-03  Canada
#
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))

df = pd.DataFrame(NAICS_Wholesale_Data, columns = ['North American Industry Classification System (NAICS)','VALUE'])

NAICS_values = pd.pivot_table(df, values ='North American Industry Classification System (NAICS)', index='North American Industry Classification System (NAICS)', aggfunc=np.mean)

#NAICS_values = pd.pivot_table(df.loc[df['North American Industry Classification System (NAICS)'] == 'Wholesale trade [41]'], values='North American Industry Classification System (NAICS)', index='North American Industry Classification System (NAICS)', aggfunc=np.mean)
#NAICS_values = NAICS_values.sort_values(by='North American Industry Classification System (NAICS)', ascending=True)

NAICS_values = NAICS_values.reset_index()
sns.barplot(data = NAICS_values, y='North American Industry Classification System (NAICS)', x='VALUE', orient = "h", color = 'cornflowerblue')
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('Average Wholesale Values (Dollar) by Industry Type (NACIS)', loc = "center", fontsize = 16)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("VALUE (MILLION DOLLAR)")
plt.ylabel("")
plt.show()

# %%
fig, ay = plt.subplots(figsize=(8, 5))

df = pd.DataFrame(NAICS_Wholesale_Data, columns = ['YEAR','VALUE'])
NAICS_values = pd.pivot_table(df, values='YEAR', index='YEAR', aggfunc=np.sum)

NAICS_values = NAICS_values.reset_index()
plt.title('Yearly total wholesale sales', loc = "center", fontsize = 16)
sns.lineplot(x = 'YEAR', y='VALUE', data = NAICS_values, linewidth = 4.5, markers = ['o'], color = 'cyan')
ay.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
sns.set_style(style='darkgrid',)
plt.xlim(0,10)
plt.ylim(400000,700000)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.ylabel("VALUE (MILLION DOLLAR)")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df2 = pd.DataFrame(NAICS_Wholesale_Data, columns = ['North American Industry Classification System (NAICS)','VALUE'])
df2
Corr_values = pd.pivot_table(df2, values='North American Industry Classification System (NAICS)', index='North American Industry Classification System (NAICS)', aggfunc=np.mean)

corr = Corr_values.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='Dark2', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df.columns)
ax.set_yticklabels(df.columns)
#plt.title('Correlation between Number of Calls and KPI\n\n\n\n\n\n\n\n\n\n\n', fontsize = 18)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

df = pd.DataFrame(NAICS_Wholesale_Data, columns = ['North American Industry Classification System (NAICS)','VALUE'])

#df3 = df.sort_values(['North American Industry Classification System (NAICS)','VALUE'], ascending = False).groupby('North American Industry Classification System (NAICS)').head(10)
#df.groupby('North American Industry Classification System (NAICS)').VALUE.nlargest(10).reset_index()

sns.boxplot(x = "VALUE", y = "North American Industry Classification System (NAICS)", orient = "h", data = df, palette = "Set2", showfliers = False)
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('Wholesale sales with minimum and maximum outlier', fontsize = 18)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("VALUE (MILLION DOLLAR)")
plt.ylabel("")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df1 = pd.DataFrame(NAICS_Wholesale_Data, columns = ['YEAR','VALUE','North American Industry Classification System (NAICS)'])
NAICS_values_Multi = pd.pivot_table(df1, index = 'YEAR', columns = 'North American Industry Classification System (NAICS)', values = 'VALUE', aggfunc = np.sum, margins = True).head(11)
pd.options.display.float_format = '${:,.2f}'.format
NAICS_values_Multi
# Out:
# North American Industry Classification System (NAICS)  Agricultural supplies merchant wholesalers [4183]  \
# YEAR
# 2009                                                                                          $15,416.00
# 2010                                                                                          $20,211.00
# 2011                                                                                          $22,620.00
# 2012                                                                                          $20,635.00
# 2013                                                                                          $22,152.00
# 2014                                                                                          $23,524.00
# 2015                                                                                          $27,401.00
# 2016                                                                                          $29,880.00
# ...

# %%
NAICS_Wholesale_Data_Sector = pd.read_csv("E:\\RU Data Science\\Major Research Project\\Data Set\\20100003.csv"
                             , header = None, names = ['REF_DATE', 'GEO', 'DGUID', 'Sales, price and volume', 'North American Industry Classification System (NAICS)', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS', 'YEAR'])
#NAICS_Wholesale_Data.head()
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop(index = NAICS_Wholesale_Data_Sector.index[0])
NAICS_Wholesale_Data_Sector.shape
NAICS_Wholesale_Data_Sector
# Out:
#      REF_DATE     GEO           DGUID  \
# 1     2004-01  Canada  2016A000011124
# 2     2004-01  Canada  2016A000011124
# 3     2004-01  Canada  2016A000011124
# 4     2004-01  Canada  2016A000011124
# 5     2004-02  Canada  2016A000011124
# ...       ...     ...             ...
# 5096  2020-03  Canada  2016A000011124
# 5097  2020-03  Canada  2016A000011124
# 5098  2020-03  Canada  2016A000011124
# 5099  2020-03  Canada  2016A000011124
# 5100  2020-03  Canada  2016A000011124
#
#                                 Sales, price and volume  \
# 1                     Wholesale sales in current prices
# 2     Wholesale sales, chained Fisher price index (2...
# 3     Wholesale sales at 2012 prices (chained Fisher...
# 4               Wholesale sales at 2012 constant prices
# 5                     Wholesale sales in current prices
# ...                                                 ...
# 5096            Wholesale sales at 2012 constant prices
# ...

# %%
df_sector = pd.DataFrame(NAICS_Wholesale_Data_Sector)
NAICS_Wholesale_Data_Sector = df_sector.fillna(0)
NAICS_Wholesale_Data_Sector['VALUE'] = NAICS_Wholesale_Data_Sector['VALUE'].astype(float)

# %%
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.set_index("North American Industry Classification System (NAICS)")
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Wholesale trade [41]", axis=0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Food merchant wholesalers [4131]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Beverage merchant wholesalers [4132]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Cigarette and tobacco product merchant wholesalers [4133]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Textile, clothing and footwear merchant wholesalers [4141]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Home entertainment equipment and household appliance merchant wholesalers [4142]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Home furnishings merchant wholesalers [4143]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Personal goods merchant wholesalers [4144]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Pharmaceuticals, toiletries, cosmetics and sundries merchant wholesalers [4145]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Pharmaceuticals and pharmacy supplies merchant wholesalers [41451]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Toiletries, cosmetics and sundries merchant wholesalers [41452]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Motor vehicle merchant wholesalers [4151]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("New motor vehicle parts and accessories merchant wholesalers [4152]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Used motor vehicle parts and accessories merchant wholesalers [4153]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Electrical, plumbing, heating and air-conditioning equipment and supplies merchant wholesalers [4161]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Metal service centres [4162]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Lumber, millwork, hardware and other building supplies merchant wholesalers [4163]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Farm, lawn and garden machinery and equipment merchant wholesalers [4171]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Construction, forestry, mining, and industrial machinery, equipment and supplies merchant wholesalers [4172]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Computer and communications equipment and supplies merchant wholesalers [4173]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Other machinery, equipment and supplies merchant wholesalers [4179]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Recyclable material merchant wholesalers [4181]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Paper, paper product and disposable plastic product merchant wholesalers [4182]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Agricultural supplies merchant wholesalers [4183]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Chemical (except agricultural) and allied product merchant wholesalers [4184]", axis = 0)
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.drop("Other miscellaneous merchant wholesalers [4189]", axis = 0)
NAICS_Wholesale_Data_Sector.shape
NAICS_Wholesale_Data_Sector
# Out:
#                                                    REF_DATE     GEO  \
# North American Industry Classification System (...
# Farm product merchant wholesalers [411]             2009-01  Canada
# Food, beverage and tobacco merchant wholesalers...  2009-01  Canada
# Personal and household goods merchant wholesale...  2009-01  Canada
# Motor vehicle and motor vehicle parts and acces...  2009-01  Canada
# Building material and supplies merchant wholesa...  2009-01  Canada
# ...                                                     ...     ...
# Personal and household goods merchant wholesale...  2020-03  Canada
# Motor vehicle and motor vehicle parts and acces...  2020-03  Canada
# Building material and supplies merchant wholesa...  2020-03  Canada
# Machinery, equipment and supplies merchant whol...  2020-03  Canada
# Miscellaneous merchant wholesalers [418]            2020-03  Canada
#
#                                                              DGUID  \
# ...

# %%
NAICS_Wholesale_Data_Sector = NAICS_Wholesale_Data_Sector.reset_index()
df_sector = pd.DataFrame(NAICS_Wholesale_Data_Sector, columns = ['North American Industry Classification System (NAICS)','VALUE'])
df_sector
# Out:
#     North American Industry Classification System (NAICS)      VALUE
# 0              Farm product merchant wholesalers [411]       $608.00
# 1    Food, beverage and tobacco merchant wholesaler...     $8,888.00
# 2    Personal and household goods merchant wholesal...     $6,559.00
# 3    Motor vehicle and motor vehicle parts and acce...     $5,063.00
# 4    Building material and supplies merchant wholes...     $5,673.00
# ..                                                 ...           ...
# 940  Personal and household goods merchant wholesal...     $9,447.00
# 941  Motor vehicle and motor vehicle parts and acce...     $8,106.00
# 942  Building material and supplies merchant wholes...     $6,936.00
# 943  Machinery, equipment and supplies merchant who...    $11,462.00
# 944           Miscellaneous merchant wholesalers [418]     $7,978.00
#
# [945 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
df_sector = pd.DataFrame(NAICS_Wholesale_Data_Sector, columns = ['North American Industry Classification System (NAICS)','VALUE'])
NAICS_values_sector = pd.pivot_table(df_sector, values='North American Industry Classification System (NAICS)', index='North American Industry Classification System (NAICS)', aggfunc=np.mean)
NAICS_values_sector = NAICS_values_sector.reset_index()
#NAICS_values = pd.pivot_table(df.loc[df['North American Industry Classification System (NAICS)'] == 'Wholesale trade [41]'], values='North American Industry Classification System (NAICS)', index='North American Industry Classification System (NAICS)', aggfunc=np.mean)
#NAICS_values = NAICS_values.sort_values(by='North American Industry Classification System (NAICS)', ascending=True)

NAICS_values_sector = NAICS_values_sector.reset_index()

sns.barplot(data = NAICS_values_sector, y = 'North American Industry Classification System (NAICS)', x = 'VALUE', orient = "h", color = 'skyblue')
ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.title('Average Wholesale Values (Dollar) by Sector', loc = "center", fontsize = 16)
plt.grid(color='grey', linestyle='-', linewidth=0.5)
plt.xlabel("VALUE (MILLION DOLLAR)")
plt.ylabel("")
plt.show()

# %%
df_sector = pd.DataFrame(NAICS_Wholesale_Data_Sector, columns = ['North American Industry Classification System (NAICS)','VALUE'])
NAICS_values_sector = pd.pivot_table(df_sector, values='North American Industry Classification System (NAICS)', index='North American Industry Classification System (NAICS)', aggfunc=np.sum)
NAICS_values_sector
NAICS_labels = ['Building material and supplies merchant wholesalers', 'Farm product merchant wholesalers', 'Food, beverage and tobacco merchant wholesalers', 'Machinery, equipment and supplies merchant wholesalers', 'Miscellaneous merchant wholesalers', 'Motor vehicle and motor vehicle parts and accessories merchant wholesalers', 'Personal and household goods merchant wholesalers']
plt.pie(NAICS_values_sector,labels=NAICS_labels,autopct='%1.1f%%')
plt.title('Industrial Sectors of Total Wholesale Sales (%)', fontsize = 16)
plt.axis('equal')
plt.show()
